# %% [markdown]
# # Guia da Camada de Transporte
# ### IMPORTANDO AS DEPENDÊNCIAS
# ##### O documento tem o objetivo de demostrar o funcionamento da camada de transporte, além de suas funções e ferramentas.

# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger

# %% [markdown]
# ##### Instanciando a rede, e setando a topologia.

# %%
rede = Network()
rede.set_ready_topology('grade',8,3,3)
rede.draw()
Logger.activate(Logger)
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %% [markdown]
# ##### Definindo os hosts alice e bob nos nós 1 e 2 respectivamente.

# %%
alice = rede.get_host(0)
bob = rede.get_host(8)

# %% [markdown]
# ##### Verificação da memória de Alice e Bob.

# %%
print('memoria de alice:',(alice.memory))
print('memoria de bob:',(bob.memory))
# Out:
# memoria de alice: []
# memoria de bob: []

# %% [markdown]
# ##### A função a seguir é chamada para que seja realizada a requesição de uma rota para que haja a transmissão de n qubits necessários. Ela vai executar toda a camada de transporte.

# %%
rede.transportlayer.run_transport_layer(0,8,11)
# Out:
# 2024-10-29 10:06:52,042: Número insuficiente de qubits na memória de Alice (Host 0). Criando mais 11 qubits para completar os 11 necessários.
# 2024-10-29 10:06:52,043: Timeslot antes da criação do qubit: 1
# 2024-10-29 10:06:52,043: Qubit 0 adicionado à memória do Host 0.
# 2024-10-29 10:06:52,044: Qubit 0 criado com fidelidade inicial 0.9858430190161982 e adicionado à memória do Host 0.
# 2024-10-29 10:06:52,044: Qubit criado para Alice (Host 0) no timeslot: 2
# 2024-10-29 10:06:52,045: Timeslot antes da criação do qubit: 3
# 2024-10-29 10:06:52,046: Qubit 1 adicionado à memória do Host 0.
# 2024-10-29 10:06:52,046: Qubit 1 criado com fidelidade inicial 0.9741023587999756 e adicionado à memória do Host 0.
# 2024-10-29 10:06:52,047: Qubit criado para Alice (Host 0) no timeslot: 4
# 2024-10-29 10:06:52,047: Timeslot antes da criação do qubit: 5
# 2024-10-29 10:06:52,048: Qubit 2 adicionado à memória do Host 0.
# 2024-10-29 10:06:52,048: Qubit 2 criado com fidelidade inicial 0.9944635237331986 e adicionado à memória do Host 0.
# 2024-10-29 10:06:52,049: Qubit criado para Alice (Host 0) no timeslot: 6
# 2024-10-29 10:06:52,049: Timeslot antes da criação do qubit: 7
# 2024-10-29 10:06:52,049: Qubit 3 adicionado à memória do Host 0.
# 2024-10-29 10:06:52,050: Qubit 3 criado com fidelidade inicial 0.9731337238186992 e adicionado à memória do Host 0.
# 2024-10-29 10:06:52,051: Qubit criado para Alice (Host 0) no timeslot: 8
# 2024-10-29 10:06:52,052: Timeslot antes da criação do qubit: 9
# 2024-10-29 10:06:52,052: Qubit 4 adicionado à memória do Host 0.
# 2024-10-29 10:06:52,053: Qubit 4 criado com fidelidade inicial 0.9853040912624395 e adicionado à memória do Host 0.
# 2024-10-29 10:06:52,053: Qubit criado para Alice (Host 0) no timeslot: 10
# 2024-10-29 10:06:52,054: Timeslot antes da criação do qubit: 11
# 2024-10-29 10:06:52,054: Qubit 5 adicionado à memória do Host 0.
# 2024-10-29 10:06:52,055: Qubit 5 criado com fidelidade inicial 0.9828386226039841 e adicionado à memória do Host 0.
# 2024-10-29 10:06:52,055: Qubit criado para Alice (Host 0) no timeslot: 12
# 2024-10-29 10:06:52,056: Timeslot antes da criação do qubit: 13
# 2024-10-29 10:06:52,056: Qubit 6 adicionado à memória do Host 0.
# 2024-10-29 10:06:52,057: Qubit 6 criado com fidelidade inicial 0.9520665278240392 e adicionado à memória do Host 0.
# 2024-10-29 10:06:52,057: Qubit criado para Alice (Host 0) no timeslot: 14
# 2024-10-29 10:06:52,059: Timeslot antes da criação do qubit: 15
# 2024-10-29 10:06:52,059: Qubit 7 adicionado à memória do Host 0.
# 2024-10-29 10:06:52,060: Qubit 7 criado com fidelidade inicial 0.9718563464889295 e adicionado à memória do Host 0.
# 2024-10-29 10:06:52,061: Qubit criado para Alice (Host 0) no timeslot: 16
# 2024-10-29 10:06:52,061: Timeslot antes da criação do qubit: 17
# 2024-10-29 10:06:52,062: Qubit 8 adicionado à memória do Host 0.
# 2024-10-29 10:06:52,062: Qubit 8 criado com fidelidade inicial 0.9719154202107316 e adicionado à memória do Host 0.
# 2024-10-29 10:06:52,063: Qubit criado para Alice (Host 0) no timeslot: 18
# 2024-10-29 10:06:52,063: Timeslot antes da criação do qubit: 19
# 2024-10-29 10:06:52,064: Qubit 9 adicionado à memória do Host 0.
# 2024-10-29 10:06:52,065: Qubit 9 criado com fidelidade inicial 0.9952201507625765 e adicionado à memória do Host 0.
# 2024-10-29 10:06:52,065: Qubit criado para Alice (Host 0) no timeslot: 20
# 2024-10-29 10:06:52,066: Timeslot antes da criação do qubit: 21
# 2024-10-29 10:06:52,067: Qubit 10 adicionado à memória do Host 0.
# 2024-10-29 10:06:52,068: Qubit 10 criado com fidelidade inicial 0.973039852257879 e adicionado à memória do Host 0.
# 2024-10-29 10:06:52,069: Qubit criado para Alice (Host 0) no timeslot: 22
# 2024-10-29 10:06:52,069: Tentativa 1 de transmissão de qubits entre 0 e 8.
# 2024-10-29 10:06:52,070: Timeslot 23: Buscando rota válida entre 0 e 8.
# 2024-10-29 10:06:52,071: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-10-29 10:06:52,073: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.16559755204225085.
# 2024-10-29 10:06:52,073: Timeslot 24: Buscando rota válida entre 0 e 8.
# 2024-10-29 10:06:52,074: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-10-29 10:06:52,075: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.11726836501900226.
# 2024-10-29 10:06:52,076: Timeslot 25: Buscando rota válida entre 0 e 8.
# 2024-10-29 10:06:52,076: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-10-29 10:06:52,077: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.2684990561650289.
# 2024-10-29 10:06:52,077: Timeslot 26: Buscando rota válida entre 0 e 8.
# 2024-10-29 10:06:52,079: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-10-29 10:06:52,080: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.2864604541477593.
# 2024-10-29 10:06:52,081: Timeslot 27: Buscando rota válida entre 0 e 8.
# 2024-10-29 10:06:52,081: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-10-29 10:06:52,082: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.3877501758587801.
# 2024-10-29 10:06:52,082: Timeslot 28: Buscando rota válida entre 0 e 8.
# 2024-10-29 10:06:52,083: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-10-29 10:06:52,084: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.1563784223433732.
# 2024-10-29 10:06:52,084: Timeslot 29: Buscando rota válida entre 0 e 8.
# 2024-10-29 10:06:52,086: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-10-29 10:06:52,087: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.14506453966188507.
# 2024-10-29 10:06:52,087: Timeslot 30: Buscando rota válida entre 0 e 8.
# 2024-10-29 10:06:52,088: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-10-29 10:06:52,088: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.009802169351449055.
# 2024-10-29 10:06:52,089: Timeslot 31: Buscando rota válida entre 0 e 8.
# 2024-10-29 10:06:52,089: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-10-29 10:06:52,089: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.14755340898500136.
# 2024-10-29 10:06:52,090: Timeslot 32: Buscando rota válida entre 0 e 8.
# 2024-10-29 10:06:52,090: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-10-29 10:06:52,091: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.15444073355255966.
# 2024-10-29 10:06:52,091: Timeslot 33: Buscando rota válida entre 0 e 8.
# 2024-10-29 10:06:52,092: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-10-29 10:06:52,093: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.612312020694111.
# 2024-10-29 10:06:52,093: Transmissão e teletransporte de 11 qubits entre 0 e 8 concluídos com sucesso. Timeslot: 33
# True

# %% [markdown]
# ##### A função get_total_useds_qubits, será usada para mostrar quantos qubits foram usados na camada de Transporte.

# %%
rede.get_total_useds_qubits()
# Out:
# 2024-10-29 10:06:52,107: Qubits usados na camada PhysicalLayer: 11
# 2024-10-29 10:06:52,108: Qubits usados na camada LinkLayer: 0
# 2024-10-29 10:06:52,109: Qubits usados na camada TransportLayer: 11
# 2024-10-29 10:06:52,109: Qubits usados na camada ApplicationLayer: 0
# 22

# %% [markdown]
# ##### Essa função apresenta uma lista de métricas do transmissão dos qubits.

# %%
rede.transportlayer.get_teleported_qubits()
# Out:
# [{'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.20866251459330656,
#   'fidelity_route': 0.7936142836436557,
#   'F_final': 0.16559755204225085,
#   'timeslot': 23,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x18cf2f2c150>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.1492575126228138,
#   'fidelity_route': 0.7856781408072182,
#   'F_final': 0.11726836501900226,
#   'timeslot': 24,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x18cf2f2d510>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.3451937297947687,
#   'fidelity_route': 0.7778213593991472,
#   'F_final': 0.2684990561650289,
#   'timeslot': 25,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x18cf1ccfe50>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.37200571904089497,
#   'fidelity_route': 0.7700431458051546,
#   'F_final': 0.2864604541477593,
#   'timeslot': 26,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x18cf53ad5d0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.5086297390417943,
#   'fidelity_route': 0.7623427143471029,
#   'F_final': 0.3877501758587801,
#   'timeslot': 27,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x18cf53adbd0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.20720077649371174,
#   'fidelity_route': 0.754719287203632,
#   'F_final': 0.1563784223433732,
#   'timeslot': 28,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x18cf53ae950>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.19415144216762628,
#   'fidelity_route': 0.7471720943315959,
#   'F_final': 0.14506453966188507,
#   'timeslot': 29,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x18cf53aef50>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.013251540358901156,
#   'fidelity_route': 0.7397003733882805,
#   'F_final': 0.009802169351449055,
#   'timeslot': 30,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x18cf53af750>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.20149218902903274,
#   'fidelity_route': 0.7323033696543968,
#   'F_final': 0.14755340898500136,
#   'timeslot': 31,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x18cf53aff10>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.2130274793570927,
#   'fidelity_route': 0.7249803359578529,
#   'F_final': 0.15444073355255966,
#   'timeslot': 32,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x18cf53b40d0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.8531224364629783,
#   'fidelity_route': 0.7177305325982745,
#   'F_final': 0.612312020694111,
#   'timeslot': 33,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x18cf53b4b90>}]

# %% [markdown]
# ##### No avg_fidelity_on_ltransportlayer, é realizada o cálculo da média da fidelidade dos ERPs criados na camada de Transporte.

# %%
rede.transportlayer.avg_fidelity_on_transportlayer()
# Out:
# 2024-10-29 10:06:52,144: Fidelidade do qubit utilizado de 0 para 8: 0.16559755204225085
# 2024-10-29 10:06:52,144: Fidelidade do qubit utilizado de 0 para 8: 0.11726836501900226
# 2024-10-29 10:06:52,145: Fidelidade do qubit utilizado de 0 para 8: 0.2684990561650289
# 2024-10-29 10:06:52,146: Fidelidade do qubit utilizado de 0 para 8: 0.2864604541477593
# 2024-10-29 10:06:52,146: Fidelidade do qubit utilizado de 0 para 8: 0.3877501758587801
# 2024-10-29 10:06:52,147: Fidelidade do qubit utilizado de 0 para 8: 0.1563784223433732
# 2024-10-29 10:06:52,147: Fidelidade do qubit utilizado de 0 para 8: 0.14506453966188507
# 2024-10-29 10:06:52,149: Fidelidade do qubit utilizado de 0 para 8: 0.009802169351449055
# 2024-10-29 10:06:52,149: Fidelidade do qubit utilizado de 0 para 8: 0.14755340898500136
# 2024-10-29 10:06:52,149: Fidelidade do qubit utilizado de 0 para 8: 0.15444073355255966
# 2024-10-29 10:06:52,150: Fidelidade do qubit utilizado de 0 para 8: 0.612312020694111
# 2024-10-29 10:06:52,151: A fidelidade média de todos os qubits utilizados na camada de transporte é 0.22282971798374554
# 0.22282971798374554

# %% [markdown]
# ##### A função get_timeslot apresenta quantos timeslot se passaram durante a execução da camada.

# %%
rede.get_timeslot()
# Out:
# 33

# %% [markdown]
# ##### Por meio do display_all_qubits_timeslot, pode-se verificar em qual timeslot cada qubit foi criado.

# %%
rede.display_all_qubit_timeslots()
# Out:
# Qubit 0 foi criado no timeslot 2
# Qubit 1 foi criado no timeslot 4
# Qubit 2 foi criado no timeslot 6
# Qubit 3 foi criado no timeslot 8
# Qubit 4 foi criado no timeslot 10
# Qubit 5 foi criado no timeslot 12
# Qubit 6 foi criado no timeslot 14
# Qubit 7 foi criado no timeslot 16
# Qubit 8 foi criado no timeslot 18
# Qubit 9 foi criado no timeslot 20
# Qubit 10 foi criado no timeslot 22
