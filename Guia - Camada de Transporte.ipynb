# %% [markdown]
# # Guia da Camada de Transporte
# ### IMPORTANDO AS DEPENDÊNCIAS
# ##### O documento tem o objetivo de demostrar o funcionamento da camada de transporte, além de suas funções e ferramentas.

# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger

# %% [markdown]
# ##### Instanciando a rede, e setando a topologia.

# %%
rede = Network()
rede.set_ready_topology('grade',8,3,3)
rede.draw()
Logger.activate(Logger)
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %% [markdown]
# ##### Definindo os hosts alice e bob nos nós 1 e 2 respectivamente.

# %%
alice = rede.get_host(0)
bob = rede.get_host(8)

# %% [markdown]
# ##### Verificação da memória de Alice e Bob.

# %%
print('memoria de alice:',(alice.memory))
print('memoria de bob:',(bob.memory))
# Out:
# memoria de alice: []
# memoria de bob: []

# %% [markdown]
# ##### A função a seguir é chamada para que seja realizada a requesição de uma rota para que haja a transmissão de n qubits necessários. Ela vai executar toda a camada de transporte.

# %%
rede.transportlayer.run_transport_layer(0,8,11)
# Out:
# 2024-11-28 16:25:19,821: Qubit 0 adicionado à memória do Host 0.
# 2024-11-28 16:25:19,821: Qubit 0 criado com fidelidade inicial 0.9761644145010249 e adicionado à memória do Host 0.
# 2024-11-28 16:25:19,823: Qubit 1 adicionado à memória do Host 0.
# 2024-11-28 16:25:19,824: Qubit 1 criado com fidelidade inicial 0.9946972193697762 e adicionado à memória do Host 0.
# 2024-11-28 16:25:19,825: Qubit 2 adicionado à memória do Host 0.
# 2024-11-28 16:25:19,825: Qubit 2 criado com fidelidade inicial 0.986173975421946 e adicionado à memória do Host 0.
# 2024-11-28 16:25:19,826: Qubit 3 adicionado à memória do Host 0.
# 2024-11-28 16:25:19,827: Qubit 3 criado com fidelidade inicial 0.9727635045120714 e adicionado à memória do Host 0.
# 2024-11-28 16:25:19,827: Qubit 4 adicionado à memória do Host 0.
# 2024-11-28 16:25:19,828: Qubit 4 criado com fidelidade inicial 0.9656365173469658 e adicionado à memória do Host 0.
# 2024-11-28 16:25:19,829: Qubit 5 adicionado à memória do Host 0.
# 2024-11-28 16:25:19,829: Qubit 5 criado com fidelidade inicial 0.9737127166080667 e adicionado à memória do Host 0.
# 2024-11-28 16:25:19,830: Qubit 6 adicionado à memória do Host 0.
# 2024-11-28 16:25:19,831: Qubit 6 criado com fidelidade inicial 0.9954369853881457 e adicionado à memória do Host 0.
# 2024-11-28 16:25:19,831: Qubit 7 adicionado à memória do Host 0.
# 2024-11-28 16:25:19,832: Qubit 7 criado com fidelidade inicial 0.9812476149435447 e adicionado à memória do Host 0.
# 2024-11-28 16:25:19,834: Qubit 8 adicionado à memória do Host 0.
# 2024-11-28 16:25:19,834: Qubit 8 criado com fidelidade inicial 0.9886798805798567 e adicionado à memória do Host 0.
# 2024-11-28 16:25:19,834: Qubit 9 adicionado à memória do Host 0.
# 2024-11-28 16:25:19,835: Qubit 9 criado com fidelidade inicial 0.9959975767258226 e adicionado à memória do Host 0.
# 2024-11-28 16:25:19,836: Qubit 10 adicionado à memória do Host 0.
# 2024-11-28 16:25:19,836: Qubit 10 criado com fidelidade inicial 0.9846286117455536 e adicionado à memória do Host 0.
# 2024-11-28 16:25:19,837: Timeslot 1: Buscando rota válida entre 0 e 8.
# 2024-11-28 16:25:19,838: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-28 16:25:19,839: Timeslot 2: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9027886410328864.
# 2024-11-28 16:25:19,840: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-28 16:25:19,841: Timeslot 3: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9780638246565252.
# 2024-11-28 16:25:19,842: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-28 16:25:19,842: Timeslot 4: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9457241045362507.
# 2024-11-28 16:25:19,842: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-28 16:25:19,843: Timeslot 5: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9601236645526335.
# 2024-11-28 16:25:19,844: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-28 16:25:19,844: Timeslot 6: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9688541731080352.
# 2024-11-28 16:25:19,845: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-28 16:25:19,846: Timeslot 7: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9604056548442503.
# 2024-11-28 16:25:19,846: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-28 16:25:19,846: Timeslot 8: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9275976253978317.
# 2024-11-28 16:25:19,849: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-28 16:25:19,850: Timeslot 9: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9142993785017494.
# 2024-11-28 16:25:19,852: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-28 16:25:19,853: Timeslot 10: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9069140031586506.
# 2024-11-28 16:25:19,854: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-28 16:25:19,854: Timeslot 11: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9699867819557428.
# 2024-11-28 16:25:19,855: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-28 16:25:19,856: Timeslot 12: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9012410568092316.
# 2024-11-28 16:25:19,857: Transmissão e teletransporte de 11 qubits entre 0 e 8 concluídos com sucesso.
# True

# %% [markdown]
# ##### A função get_total_useds_qubits, será usada para mostrar quantos qubits foram usados na camada de Transporte.

# %%
rede.get_total_useds_qubits()
# Out:
# 2024-11-28 16:25:19,901: Qubits usados na camada PhysicalLayer: 11
# 2024-11-28 16:25:19,902: Qubits usados na camada LinkLayer: 0
# 2024-11-28 16:25:19,903: Qubits usados na camada TransportLayer: 11
# 2024-11-28 16:25:19,903: Qubits usados na camada ApplicationLayer: 0
# 22

# %% [markdown]
# ##### Essa função apresenta uma lista de métricas do transmissão dos qubits.

# %%
rede.transportlayer.get_teleported_qubits()
# Out:
# [{'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9028789289257789,
#   'fidelity_route': 0.9999,
#   'F_final': 0.9027886410328864,
#   'timeslot': 2,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d3c0a533d0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9782594667672839,
#   'fidelity_route': 0.9998000100000001,
#   'F_final': 0.9780638246565252,
#   'timeslot': 3,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d3c328f490>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9460078785205164,
#   'fidelity_route': 0.9997000299990001,
#   'F_final': 0.9457241045362507,
#   'timeslot': 4,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d3c3286750>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9605078100500267,
#   'fidelity_route': 0.9996000599960002,
#   'F_final': 0.9601236645526335,
#   'timeslot': 5,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d3c3216990>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9693387455566317,
#   'fidelity_route': 0.9995000999900007,
#   'F_final': 0.9688541731080352,
#   'timeslot': 6,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d3a153f1d0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.960982099976139,
#   'fidelity_route': 0.9994001499800017,
#   'F_final': 0.9604056548442503,
#   'timeslot': 7,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d3c32c0e90>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9282472035408829,
#   'fidelity_route': 0.9993002099650037,
#   'F_final': 0.9275976253978317,
#   'timeslot': 8,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d3c3298510>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.915031147262073,
#   'fidelity_route': 0.9992002799440072,
#   'F_final': 0.9142993785017494,
#   'timeslot': 9,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d3c32df490>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9077306340224803,
#   'fidelity_route': 0.9991003599160128,
#   'F_final': 0.9069140031586506,
#   'timeslot': 10,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d3c3216950>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.970957302443895,
#   'fidelity_route': 0.9990004498800211,
#   'F_final': 0.9699867819557428,
#   'timeslot': 11,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d3c32e1910>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9022330170486643,
#   'fidelity_route': 0.9989005498350332,
#   'F_final': 0.9012410568092316,
#   'timeslot': 12,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1d3c3270c10>}]

# %% [markdown]
# ##### No avg_fidelity_on_ltransportlayer, é realizada o cálculo da média da fidelidade dos ERPs criados na camada de Transporte.

# %%
rede.transportlayer.avg_fidelity_on_transportlayer()
# Out:
# 2024-11-28 16:25:19,928: Fidelidade do qubit utilizado de 0 para 8: 0.9027886410328864
# 2024-11-28 16:25:19,929: Fidelidade do qubit utilizado de 0 para 8: 0.9780638246565252
# 2024-11-28 16:25:19,930: Fidelidade do qubit utilizado de 0 para 8: 0.9457241045362507
# 2024-11-28 16:25:19,930: Fidelidade do qubit utilizado de 0 para 8: 0.9601236645526335
# 2024-11-28 16:25:19,931: Fidelidade do qubit utilizado de 0 para 8: 0.9688541731080352
# 2024-11-28 16:25:19,932: Fidelidade do qubit utilizado de 0 para 8: 0.9604056548442503
# 2024-11-28 16:25:19,933: Fidelidade do qubit utilizado de 0 para 8: 0.9275976253978317
# 2024-11-28 16:25:19,933: Fidelidade do qubit utilizado de 0 para 8: 0.9142993785017494
# 2024-11-28 16:25:19,934: Fidelidade do qubit utilizado de 0 para 8: 0.9069140031586506
# 2024-11-28 16:25:19,934: Fidelidade do qubit utilizado de 0 para 8: 0.9699867819557428
# 2024-11-28 16:25:19,935: Fidelidade do qubit utilizado de 0 para 8: 0.9012410568092316
# 2024-11-28 16:25:19,935: A fidelidade média de todos os qubits utilizados na camada de transporte é 0.9396362644139807
# 0.9396362644139807

# %% [markdown]
# ##### A função get_timeslot apresenta quantos timeslot se passaram durante a execução da camada.

# %%
rede.get_timeslot()
# Out:
# 12

# %% [markdown]
# ##### Por meio do display_all_qubits_timeslot, pode-se verificar em qual timeslot cada qubit foi criado.

# %%
rede.display_all_qubit_timeslots()
# Out:
# Qubit 0 foi criado no timeslot 0
# Qubit 1 foi criado no timeslot 0
# Qubit 2 foi criado no timeslot 0
# Qubit 3 foi criado no timeslot 0
# Qubit 4 foi criado no timeslot 0
# Qubit 5 foi criado no timeslot 0
# Qubit 6 foi criado no timeslot 0
# Qubit 7 foi criado no timeslot 0
# Qubit 8 foi criado no timeslot 0
# Qubit 9 foi criado no timeslot 0
# Qubit 10 foi criado no timeslot 0
