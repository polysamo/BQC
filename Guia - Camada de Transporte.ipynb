# %% [markdown]
# # Guia da Camada de Transporte
# ### IMPORTANDO AS DEPENDÊNCIAS
# ##### O documento tem o objetivo de demostrar o funcionamento da camada de transporte, além de suas funções e ferramentas.

# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger

# %% [markdown]
# ##### Instanciando a rede, e setando a topologia.

# %%
rede = Network()
rede.set_ready_topology('grade',8,3,3)
rede.draw()
Logger.activate(Logger)
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %% [markdown]
# ##### Definindo os hosts alice e bob nos nós 1 e 2 respectivamente.

# %%
alice = rede.get_host(0)
bob = rede.get_host(8)

# %% [markdown]
# ##### Verificação da memória de Alice e Bob.

# %%
print('memoria de alice:',(alice.memory))
print('memoria de bob:',(bob.memory))
# Out:
# memoria de alice: []
# memoria de bob: []

# %% [markdown]
# ##### A função a seguir é chamada para que seja realizada a requesição de uma rota para que haja a transmissão de n qubits necessários. Ela vai executar toda a camada de transporte.

# %%
rede.transportlayer.run_transport_layer(0,8,11)
# Out:
# 2024-11-18 09:40:58,938: Qubit 0 adicionado à memória do Host 0.
# 2024-11-18 09:40:58,939: Qubit 0 criado com fidelidade inicial 0.9871005536565007 e adicionado à memória do Host 0.
# 2024-11-18 09:40:58,942: Qubit 1 adicionado à memória do Host 0.
# 2024-11-18 09:40:58,943: Qubit 1 criado com fidelidade inicial 0.9655429328329209 e adicionado à memória do Host 0.
# 2024-11-18 09:40:58,944: Qubit 2 adicionado à memória do Host 0.
# 2024-11-18 09:40:58,944: Qubit 2 criado com fidelidade inicial 0.9970634057497229 e adicionado à memória do Host 0.
# 2024-11-18 09:40:58,945: Qubit 3 adicionado à memória do Host 0.
# 2024-11-18 09:40:58,946: Qubit 3 criado com fidelidade inicial 0.9559860384380939 e adicionado à memória do Host 0.
# 2024-11-18 09:40:58,946: Qubit 4 adicionado à memória do Host 0.
# 2024-11-18 09:40:58,947: Qubit 4 criado com fidelidade inicial 0.9794281248593201 e adicionado à memória do Host 0.
# 2024-11-18 09:40:58,948: Qubit 5 adicionado à memória do Host 0.
# 2024-11-18 09:40:58,949: Qubit 5 criado com fidelidade inicial 0.9876916658231844 e adicionado à memória do Host 0.
# 2024-11-18 09:40:58,949: Qubit 6 adicionado à memória do Host 0.
# 2024-11-18 09:40:58,949: Qubit 6 criado com fidelidade inicial 0.9643468416645629 e adicionado à memória do Host 0.
# 2024-11-18 09:40:58,952: Qubit 7 adicionado à memória do Host 0.
# 2024-11-18 09:40:58,952: Qubit 7 criado com fidelidade inicial 0.9860013819767087 e adicionado à memória do Host 0.
# 2024-11-18 09:40:58,953: Qubit 8 adicionado à memória do Host 0.
# 2024-11-18 09:40:58,954: Qubit 8 criado com fidelidade inicial 0.9856031154453428 e adicionado à memória do Host 0.
# 2024-11-18 09:40:58,954: Qubit 9 adicionado à memória do Host 0.
# 2024-11-18 09:40:58,955: Qubit 9 criado com fidelidade inicial 0.9795258090987571 e adicionado à memória do Host 0.
# 2024-11-18 09:40:58,955: Qubit 10 adicionado à memória do Host 0.
# 2024-11-18 09:40:58,956: Qubit 10 criado com fidelidade inicial 0.9965119646453615 e adicionado à memória do Host 0.
# 2024-11-18 09:40:58,958: Timeslot 23: Buscando rota válida entre 0 e 8.
# 2024-11-18 09:40:58,959: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-11-18 09:40:58,960: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.4052724481665894.
# 2024-11-18 09:40:58,960: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-18 09:40:58,961: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.23349848340577875.
# 2024-11-18 09:40:58,961: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-18 09:40:58,962: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.48855266899803296.
# 2024-11-18 09:40:58,962: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-18 09:40:58,963: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.6184953729378392.
# 2024-11-18 09:40:58,964: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-18 09:40:58,964: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.18870536579726774.
# 2024-11-18 09:40:58,965: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-18 09:40:58,965: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.20803498213298605.
# 2024-11-18 09:40:58,967: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-18 09:40:58,967: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.02019229619429275.
# 2024-11-18 09:40:58,969: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-18 09:40:58,971: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.007739741949760371.
# 2024-11-18 09:40:58,972: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-18 09:40:58,972: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.4115579509198369.
# 2024-11-18 09:40:58,973: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-18 09:40:58,973: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.13935234466120797.
# 2024-11-18 09:40:58,974: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-11-18 09:40:58,975: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.44600113444386613.
# 2024-11-18 09:40:58,975: Transmissão e teletransporte de 11 qubits entre 0 e 8 concluídos com sucesso.
# True

# %% [markdown]
# ##### A função get_total_useds_qubits, será usada para mostrar quantos qubits foram usados na camada de Transporte.

# %%
rede.get_total_useds_qubits()
# Out:
# 2024-11-18 09:40:58,989: Qubits usados na camada PhysicalLayer: 11
# 2024-11-18 09:40:58,989: Qubits usados na camada LinkLayer: 0
# 2024-11-18 09:40:58,989: Qubits usados na camada TransportLayer: 11
# 2024-11-18 09:40:58,993: Qubits usados na camada ApplicationLayer: 0
# 22

# %% [markdown]
# ##### Essa função apresenta uma lista de métricas do transmissão dos qubits.

# %%
rede.transportlayer.get_teleported_qubits()
# Out:
# [{'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.5106667766939573,
#   'fidelity_route': 0.7936142836436553,
#   'F_final': 0.4052724481665894,
#   'timeslot': 23,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1f93ee7d010>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.29422162405361024,
#   'fidelity_route': 0.7936142836436553,
#   'F_final': 0.23349848340577875,
#   'timeslot': 23,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1f93ee2e590>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.6156046823590192,
#   'fidelity_route': 0.7936142836436553,
#   'F_final': 0.48855266899803296,
#   'timeslot': 23,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1f93ee42a50>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.7793400215759636,
#   'fidelity_route': 0.7936142836436553,
#   'F_final': 0.6184953729378392,
#   'timeslot': 23,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1f93eeb92d0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.23777969939109525,
#   'fidelity_route': 0.7936142836436553,
#   'F_final': 0.18870536579726774,
#   'timeslot': 23,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1f93eeba650>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.26213613643375006,
#   'fidelity_route': 0.7936142836436553,
#   'F_final': 0.20803498213298605,
#   'timeslot': 23,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1f93eee2710>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.025443463670519563,
#   'fidelity_route': 0.7936142836436553,
#   'F_final': 0.02019229619429275,
#   'timeslot': 23,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1f93ee40790>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.009752523498223264,
#   'fidelity_route': 0.7936142836436553,
#   'F_final': 0.007739741949760371,
#   'timeslot': 23,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1f93eee1c90>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.5185868745082121,
#   'fidelity_route': 0.7936142836436553,
#   'F_final': 0.4115579509198369,
#   'timeslot': 23,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1f93eee3310>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.17559203196471104,
#   'fidelity_route': 0.7936142836436553,
#   'F_final': 0.13935234466120797,
#   'timeslot': 23,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1f93eee2390>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.5619872822804779,
#   'fidelity_route': 0.7936142836436553,
#   'F_final': 0.44600113444386613,
#   'timeslot': 23,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x1f93eee3f50>}]

# %% [markdown]
# ##### No avg_fidelity_on_ltransportlayer, é realizada o cálculo da média da fidelidade dos ERPs criados na camada de Transporte.

# %%
rede.transportlayer.avg_fidelity_on_transportlayer()
# Out:
# 2024-11-18 09:40:59,068: Fidelidade do qubit utilizado de 0 para 8: 0.4052724481665894
# 2024-11-18 09:40:59,069: Fidelidade do qubit utilizado de 0 para 8: 0.23349848340577875
# 2024-11-18 09:40:59,070: Fidelidade do qubit utilizado de 0 para 8: 0.48855266899803296
# 2024-11-18 09:40:59,071: Fidelidade do qubit utilizado de 0 para 8: 0.6184953729378392
# 2024-11-18 09:40:59,072: Fidelidade do qubit utilizado de 0 para 8: 0.18870536579726774
# 2024-11-18 09:40:59,072: Fidelidade do qubit utilizado de 0 para 8: 0.20803498213298605
# 2024-11-18 09:40:59,073: Fidelidade do qubit utilizado de 0 para 8: 0.02019229619429275
# 2024-11-18 09:40:59,073: Fidelidade do qubit utilizado de 0 para 8: 0.007739741949760371
# 2024-11-18 09:40:59,074: Fidelidade do qubit utilizado de 0 para 8: 0.4115579509198369
# 2024-11-18 09:40:59,074: Fidelidade do qubit utilizado de 0 para 8: 0.13935234466120797
# 2024-11-18 09:40:59,075: Fidelidade do qubit utilizado de 0 para 8: 0.44600113444386613
# 2024-11-18 09:40:59,075: A fidelidade média de todos os qubits utilizados na camada de transporte é 0.2879457081461326
# 0.2879457081461326

# %% [markdown]
# ##### A função get_timeslot apresenta quantos timeslot se passaram durante a execução da camada.

# %%
rede.get_timeslot()
# Out:
# 23

# %% [markdown]
# ##### Por meio do display_all_qubits_timeslot, pode-se verificar em qual timeslot cada qubit foi criado.

# %%
rede.display_all_qubit_timeslots()
# Out:
# Qubit 0 foi criado no timeslot 2
# Qubit 1 foi criado no timeslot 4
# Qubit 2 foi criado no timeslot 6
# Qubit 3 foi criado no timeslot 8
# Qubit 4 foi criado no timeslot 10
# Qubit 5 foi criado no timeslot 12
# Qubit 6 foi criado no timeslot 14
# Qubit 7 foi criado no timeslot 16
# Qubit 8 foi criado no timeslot 18
# Qubit 9 foi criado no timeslot 20
# Qubit 10 foi criado no timeslot 22
