# %% [markdown]
# # Guia da Camada de Transporte
# ### IMPORTANDO AS DEPENDÊNCIAS
# ##### O documento tem o objetivo de demostrar o funcionamento da camada de transporte, além de suas funções e ferramentas.

# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger

# %% [markdown]
# ##### Instanciando a rede, e setando a topologia.

# %%
rede = Network()
rede.set_ready_topology('grade',8,3,3)
rede.draw()
Logger.activate(Logger)
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %% [markdown]
# ##### Definindo os hosts alice e bob nos nós 1 e 2 respectivamente.

# %%
alice = rede.get_host(0)
bob = rede.get_host(8)

# %% [markdown]
# ##### Verificação da memória de Alice e Bob.

# %%
print('memoria de alice:',(alice.memory))
print('memoria de bob:',(bob.memory))
# Out:
# memoria de alice: []
# memoria de bob: []

# %% [markdown]
# ##### A função a seguir é chamada para que seja realizada a requesição de uma rota para que haja a transmissão de n qubits necessários. Ela vai executar toda a camada de transporte.

# %%
# rede.transportlayer.run_transport_layer(0,8,11)
rede.transportlayer.run_transport_layer_eprs(0,8,10)
# Out:
# 2024-12-13 12:27:34,276: Qubit 0 adicionado à memória do Host 0.
# 2024-12-13 12:27:34,277: Qubit 0 criado com fidelidade inicial 0.9879420402765372 e adicionado à memória do Host 0.
# 2024-12-13 12:27:34,278: Qubit 1 adicionado à memória do Host 0.
# 2024-12-13 12:27:34,279: Qubit 1 criado com fidelidade inicial 0.9910855203181677 e adicionado à memória do Host 0.
# 2024-12-13 12:27:34,279: Qubit 2 adicionado à memória do Host 0.
# 2024-12-13 12:27:34,282: Qubit 2 criado com fidelidade inicial 0.9653573519479921 e adicionado à memória do Host 0.
# 2024-12-13 12:27:34,283: Qubit 3 adicionado à memória do Host 0.
# 2024-12-13 12:27:34,284: Qubit 3 criado com fidelidade inicial 0.9509950161732598 e adicionado à memória do Host 0.
# 2024-12-13 12:27:34,285: Qubit 4 adicionado à memória do Host 0.
# 2024-12-13 12:27:34,286: Qubit 4 criado com fidelidade inicial 0.9872672389469259 e adicionado à memória do Host 0.
# 2024-12-13 12:27:34,287: Qubit 5 adicionado à memória do Host 0.
# 2024-12-13 12:27:34,288: Qubit 5 criado com fidelidade inicial 0.9640777111287625 e adicionado à memória do Host 0.
# 2024-12-13 12:27:34,289: Qubit 6 adicionado à memória do Host 0.
# 2024-12-13 12:27:34,290: Qubit 6 criado com fidelidade inicial 0.9745240208499606 e adicionado à memória do Host 0.
# 2024-12-13 12:27:34,290: Qubit 7 adicionado à memória do Host 0.
# 2024-12-13 12:27:34,291: Qubit 7 criado com fidelidade inicial 0.9846047976328811 e adicionado à memória do Host 0.
# 2024-12-13 12:27:34,291: Qubit 8 adicionado à memória do Host 0.
# 2024-12-13 12:27:34,291: Qubit 8 criado com fidelidade inicial 0.9810164618370392 e adicionado à memória do Host 0.
# 2024-12-13 12:27:34,292: Qubit 9 adicionado à memória do Host 0.
# 2024-12-13 12:27:34,293: Qubit 9 criado com fidelidade inicial 0.9711259430902027 e adicionado à memória do Host 0.
# 2024-12-13 12:27:34,294: Rota válida encontrada: [0, 3, 6, 7, 8]
# 2024-12-13 12:27:34,295: Fidelidade do EPR 0->3: 1.0
# 2024-12-13 12:27:34,295: Fidelidade do EPR 3->6: 1.0
# 2024-12-13 12:27:34,295: Fidelidade do EPR 6->7: 1.0
# 2024-12-13 12:27:34,296: Fidelidade do EPR 7->8: 1.0
# 2024-12-13 12:27:34,297: Produto das fidelidades para rota [0, 3, 6, 7, 8]: 1.0
# 2024-12-13 12:27:34,298: Fidelidade atual da rota: 1.0
# 2024-12-13 12:27:34,298: Rota 0 -> 3 tem 20 pares EPRs disponíveis.
# 2024-12-13 12:27:34,300: Rota 3 -> 6 tem 20 pares EPRs disponíveis.
# 2024-12-13 12:27:34,300: Rota 6 -> 7 tem 20 pares EPRs disponíveis.
# 2024-12-13 12:27:34,301: Rota 7 -> 8 tem 20 pares EPRs disponíveis.
# 2024-12-13 12:27:34,301: Fidelidade final calculada: 0.9791495535209449 (F_qubit: 0.9791495535209449 * F_rota: 1.0)
# 2024-12-13 12:27:34,302: Timeslot 1: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9791495535209449.
# 2024-12-13 12:27:34,302: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-12-13 12:27:34,303: Fidelidade do EPR 0->3: 0.999
# 2024-12-13 12:27:34,303: Fidelidade do EPR 3->6: 0.999
# 2024-12-13 12:27:34,304: Fidelidade do EPR 6->7: 0.999
# 2024-12-13 12:27:34,304: Fidelidade do EPR 7->8: 0.999
# 2024-12-13 12:27:34,305: Produto das fidelidades para rota [0, 3, 6, 7, 8]: 0.996005996001
# 2024-12-13 12:27:34,306: Fidelidade atual da rota: 0.996005996001
# 2024-12-13 12:27:34,307: Rota 0 -> 3 tem 19 pares EPRs disponíveis.
# 2024-12-13 12:27:34,307: Rota 3 -> 6 tem 19 pares EPRs disponíveis.
# 2024-12-13 12:27:34,308: Rota 6 -> 7 tem 19 pares EPRs disponíveis.
# 2024-12-13 12:27:34,309: Rota 7 -> 8 tem 19 pares EPRs disponíveis.
# 2024-12-13 12:27:34,309: Fidelidade final calculada: 0.9676509697368731 (F_qubit: 0.9686195893261993 * F_rota: 0.999)
# 2024-12-13 12:27:34,310: Timeslot 2: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9676509697368731.
# 2024-12-13 12:27:34,310: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-12-13 12:27:34,312: Fidelidade do EPR 0->3: 0.998001
# 2024-12-13 12:27:34,312: Fidelidade do EPR 3->6: 0.998001
# 2024-12-13 12:27:34,313: Fidelidade do EPR 6->7: 0.998001
# 2024-12-13 12:27:34,314: Fidelidade do EPR 7->8: 0.998001
# 2024-12-13 12:27:34,314: Produto das fidelidades para rota [0, 3, 6, 7, 8]: 0.9920279440699442
# 2024-12-13 12:27:34,314: Fidelidade atual da rota: 0.9920279440699442
# 2024-12-13 12:27:34,315: Rota 0 -> 3 tem 18 pares EPRs disponíveis.
# 2024-12-13 12:27:34,316: Rota 3 -> 6 tem 18 pares EPRs disponíveis.
# 2024-12-13 12:27:34,317: Rota 6 -> 7 tem 18 pares EPRs disponíveis.
# 2024-12-13 12:27:34,318: Rota 7 -> 8 tem 18 pares EPRs disponíveis.
# 2024-12-13 12:27:34,318: Fidelidade final calculada: 0.9617878910182779 (F_qubit: 0.9637143560159538 * F_rota: 0.998001)
# 2024-12-13 12:27:34,320: Timeslot 3: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9617878910182779.
# 2024-12-13 12:27:34,321: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-12-13 12:27:34,323: Fidelidade do EPR 0->3: 0.997002999
# 2024-12-13 12:27:34,324: Fidelidade do EPR 3->6: 0.997002999
# 2024-12-13 12:27:34,325: Fidelidade do EPR 6->7: 0.997002999
# 2024-12-13 12:27:34,326: Fidelidade do EPR 7->8: 0.997002999
# 2024-12-13 12:27:34,326: Produto das fidelidades para rota [0, 3, 6, 7, 8]: 0.9880657804942089
# 2024-12-13 12:27:34,327: Fidelidade atual da rota: 0.9880657804942089
# 2024-12-13 12:27:34,328: Rota 0 -> 3 tem 17 pares EPRs disponíveis.
# 2024-12-13 12:27:34,330: Rota 3 -> 6 tem 17 pares EPRs disponíveis.
# 2024-12-13 12:27:34,330: Rota 6 -> 7 tem 17 pares EPRs disponíveis.
# 2024-12-13 12:27:34,331: Rota 7 -> 8 tem 17 pares EPRs disponíveis.
# 2024-12-13 12:27:34,333: Fidelidade final calculada: 0.9917396851769184 (F_qubit: 0.9947208646028539 * F_rota: 0.997002999)
# 2024-12-13 12:27:34,334: Timeslot 4: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9917396851769184.
# 2024-12-13 12:27:34,335: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-12-13 12:27:34,336: Fidelidade do EPR 0->3: 0.996005996001
# 2024-12-13 12:27:34,337: Fidelidade do EPR 3->6: 0.996005996001
# 2024-12-13 12:27:34,338: Fidelidade do EPR 6->7: 0.996005996001
# 2024-12-13 12:27:34,338: Fidelidade do EPR 7->8: 0.996005996001
# 2024-12-13 12:27:34,340: Produto das fidelidades para rota [0, 3, 6, 7, 8]: 0.9841194418156402
# 2024-12-13 12:27:34,341: Fidelidade atual da rota: 0.9841194418156402
# 2024-12-13 12:27:34,342: Rota 0 -> 3 tem 16 pares EPRs disponíveis.
# 2024-12-13 12:27:34,343: Rota 3 -> 6 tem 16 pares EPRs disponíveis.
# 2024-12-13 12:27:34,344: Rota 6 -> 7 tem 16 pares EPRs disponíveis.
# 2024-12-13 12:27:34,344: Rota 7 -> 8 tem 16 pares EPRs disponíveis.
# 2024-12-13 12:27:34,345: Fidelidade final calculada: 0.9786624059537014 (F_qubit: 0.9825868618091318 * F_rota: 0.996005996001)
# 2024-12-13 12:27:34,346: Timeslot 5: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9786624059537014.
# 2024-12-13 12:27:34,347: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-12-13 12:27:34,347: Fidelidade do EPR 0->3: 0.995009990004999
# 2024-12-13 12:27:34,348: Fidelidade do EPR 3->6: 0.995009990004999
# 2024-12-13 12:27:34,350: Fidelidade do EPR 6->7: 0.995009990004999
# 2024-12-13 12:27:34,351: Fidelidade do EPR 7->8: 0.995009990004999
# 2024-12-13 12:27:34,357: Produto das fidelidades para rota [0, 3, 6, 7, 8]: 0.9801888648295347
# 2024-12-13 12:27:34,375: Fidelidade atual da rota: 0.9801888648295347
# 2024-12-13 12:27:34,382: Rota 0 -> 3 tem 15 pares EPRs disponíveis.
# 2024-12-13 12:27:34,386: Rota 3 -> 6 tem 15 pares EPRs disponíveis.
# 2024-12-13 12:27:34,395: Rota 6 -> 7 tem 15 pares EPRs disponíveis.
# 2024-12-13 12:27:34,397: Rota 7 -> 8 tem 15 pares EPRs disponíveis.
# 2024-12-13 12:27:34,397: Fidelidade final calculada: 0.9696520023485338 (F_qubit: 0.9745148411461297 * F_rota: 0.995009990004999)
# 2024-12-13 12:27:34,398: Timeslot 6: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9696520023485338.
# 2024-12-13 12:27:34,399: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-12-13 12:27:34,400: Fidelidade do EPR 0->3: 0.994014980014994
# 2024-12-13 12:27:34,404: Fidelidade do EPR 3->6: 0.994014980014994
# 2024-12-13 12:27:34,406: Fidelidade do EPR 6->7: 0.994014980014994
# 2024-12-13 12:27:34,408: Fidelidade do EPR 7->8: 0.994014980014994
# 2024-12-13 12:27:34,410: Produto das fidelidades para rota [0, 3, 6, 7, 8]: 0.9762739865836302
# 2024-12-13 12:27:34,428: Fidelidade atual da rota: 0.9762739865836302
# 2024-12-13 12:27:34,431: Rota 0 -> 3 tem 14 pares EPRs disponíveis.
# 2024-12-13 12:27:34,433: Rota 3 -> 6 tem 14 pares EPRs disponíveis.
# 2024-12-13 12:27:34,433: Rota 6 -> 7 tem 14 pares EPRs disponíveis.
# 2024-12-13 12:27:34,434: Rota 7 -> 8 tem 14 pares EPRs disponíveis.
# 2024-12-13 12:27:34,435: Fidelidade final calculada: 0.9791776232400563 (F_qubit: 0.9850733066671552 * F_rota: 0.994014980014994)
# 2024-12-13 12:27:34,436: Timeslot 7: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9791776232400563.
# 2024-12-13 12:27:34,436: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-12-13 12:27:34,437: Fidelidade do EPR 0->3: 0.993020965034979
# 2024-12-13 12:27:34,437: Fidelidade do EPR 3->6: 0.993020965034979
# 2024-12-13 12:27:34,439: Fidelidade do EPR 6->7: 0.993020965034979
# 2024-12-13 12:27:34,439: Fidelidade do EPR 7->8: 0.993020965034979
# 2024-12-13 12:27:34,440: Produto das fidelidades para rota [0, 3, 6, 7, 8]: 0.9723747443770957
# 2024-12-13 12:27:34,441: Fidelidade atual da rota: 0.9723747443770957
# 2024-12-13 12:27:34,441: Rota 0 -> 3 tem 13 pares EPRs disponíveis.
# 2024-12-13 12:27:34,442: Rota 3 -> 6 tem 13 pares EPRs disponíveis.
# 2024-12-13 12:27:34,443: Rota 6 -> 7 tem 13 pares EPRs disponíveis.
# 2024-12-13 12:27:34,445: Rota 7 -> 8 tem 13 pares EPRs disponíveis.
# 2024-12-13 12:27:34,447: Fidelidade final calculada: 0.9025891738930174 (F_qubit: 0.9089326466145896 * F_rota: 0.993020965034979)
# 2024-12-13 12:27:34,447: Timeslot 8: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9025891738930174.
# 2024-12-13 12:27:34,448: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-12-13 12:27:34,448: Fidelidade do EPR 0->3: 0.9920279440699441
# 2024-12-13 12:27:34,448: Fidelidade do EPR 3->6: 0.9920279440699441
# 2024-12-13 12:27:34,450: Fidelidade do EPR 6->7: 0.9920279440699441
# 2024-12-13 12:27:34,450: Fidelidade do EPR 7->8: 0.9920279440699441
# 2024-12-13 12:27:34,451: Produto das fidelidades para rota [0, 3, 6, 7, 8]: 0.9684910757595272
# 2024-12-13 12:27:34,451: Fidelidade atual da rota: 0.9684910757595272
# 2024-12-13 12:27:34,452: Rota 0 -> 3 tem 12 pares EPRs disponíveis.
# 2024-12-13 12:27:34,452: Rota 3 -> 6 tem 12 pares EPRs disponíveis.
# 2024-12-13 12:27:34,452: Rota 6 -> 7 tem 12 pares EPRs disponíveis.
# 2024-12-13 12:27:34,453: Rota 7 -> 8 tem 12 pares EPRs disponíveis.
# 2024-12-13 12:27:34,453: Fidelidade final calculada: 0.9016563096055864 (F_qubit: 0.9089021282065962 * F_rota: 0.9920279440699441)
# 2024-12-13 12:27:34,462: Timeslot 9: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9016563096055864.
# 2024-12-13 12:27:34,467: Usando a rota fornecida: [0, 3, 6, 7, 8]
# 2024-12-13 12:27:34,470: Fidelidade do EPR 0->3: 0.9910359161258742
# 2024-12-13 12:27:34,471: Fidelidade do EPR 3->6: 0.9910359161258742
# 2024-12-13 12:27:34,471: Fidelidade do EPR 6->7: 0.9910359161258742
# 2024-12-13 12:27:34,472: Fidelidade do EPR 7->8: 0.9910359161258742
# 2024-12-13 12:27:34,472: Produto das fidelidades para rota [0, 3, 6, 7, 8]: 0.9646229185299477
# 2024-12-13 12:27:34,473: Fidelidade atual da rota: 0.9646229185299477
# 2024-12-13 12:27:34,473: Rota 0 -> 3 tem 11 pares EPRs disponíveis.
# 2024-12-13 12:27:34,474: Rota 3 -> 6 tem 11 pares EPRs disponíveis.
# 2024-12-13 12:27:34,475: Rota 6 -> 7 tem 11 pares EPRs disponíveis.
# 2024-12-13 12:27:34,476: Rota 7 -> 8 tem 11 pares EPRs disponíveis.
# 2024-12-13 12:27:34,477: Fidelidade final calculada: 0.9529766015417566 (F_qubit: 0.9615964326167937 * F_rota: 0.9910359161258742)
# 2024-12-13 12:27:34,477: Timeslot 10: Teletransporte de qubit de 0 para 8 na rota [0, 3, 6, 7, 8] foi bem-sucedido com fidelidade final de 0.9529766015417566.
# 2024-12-13 12:27:34,478: Foram utilizados 40 pares EPRs ao longo da transmissão.
# 2024-12-13 12:27:34,479: Transmissão e teletransporte de 10 qubits entre 0 e 8 concluídos com sucesso.
# True

# %% [markdown]
# ##### A função get_total_useds_qubits, será usada para mostrar quantos qubits foram usados na camada de Transporte.

# %%
rede.get_total_useds_qubits()
# Out:
# 2024-12-13 12:27:34,488: Qubits usados na camada PhysicalLayer: 10
# 2024-12-13 12:27:34,490: Qubits usados na camada LinkLayer: 0
# 2024-12-13 12:27:34,490: Qubits usados na camada TransportLayer: 10
# 2024-12-13 12:27:34,491: Qubits usados na camada ApplicationLayer: 0
# 20

# %% [markdown]
# ##### Essa função apresenta uma lista de métricas do transmissão dos qubits.

# %%
rede.transportlayer.get_teleported_qubits()
# Out:
# [{'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9791495535209449,
#   'fidelity_route': 1.0,
#   'F_final': 0.9791495535209449,
#   'timeslot': 1,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x236f257ae90>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9686195893261993,
#   'fidelity_route': 0.999,
#   'F_final': 0.9676509697368731,
#   'timeslot': 2,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x236f2588fd0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9637143560159538,
#   'fidelity_route': 0.998001,
#   'F_final': 0.9617878910182779,
#   'timeslot': 3,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x236f24f2e50>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9947208646028539,
#   'fidelity_route': 0.997002999,
#   'F_final': 0.9917396851769184,
#   'timeslot': 4,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x236f2598250>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9825868618091318,
#   'fidelity_route': 0.996005996001,
#   'F_final': 0.9786624059537014,
#   'timeslot': 5,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x236f25bd690>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9745148411461297,
#   'fidelity_route': 0.995009990004999,
#   'F_final': 0.9696520023485338,
#   'timeslot': 6,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x236f25b7490>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9850733066671552,
#   'fidelity_route': 0.994014980014994,
#   'F_final': 0.9791776232400563,
#   'timeslot': 7,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x236f25a57d0>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9089326466145896,
#   'fidelity_route': 0.993020965034979,
#   'F_final': 0.9025891738930174,
#   'timeslot': 8,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x236f2552a10>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9089021282065962,
#   'fidelity_route': 0.9920279440699441,
#   'F_final': 0.9016563096055864,
#   'timeslot': 9,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x236f257b010>},
#  {'alice_id': 0,
#   'bob_id': 8,
#   'route': [0, 3, 6, 7, 8],
#   'fidelity_alice': 0.9615964326167937,
#   'fidelity_route': 0.9910359161258742,
#   'F_final': 0.9529766015417566,
#   'timeslot': 10,
#   'qubit': <quantumnet.objects.qubit.Qubit at 0x236f25b4810>}]

# %% [markdown]
# ##### No avg_fidelity_on_ltransportlayer, é realizada o cálculo da média da fidelidade dos ERPs criados na camada de Transporte.

# %%
rede.transportlayer.avg_fidelity_on_transportlayer()
# Out:
# 2024-12-13 12:27:34,520: Fidelidade do qubit utilizado de 0 para 8: 0.9791495535209449
# 2024-12-13 12:27:34,522: Fidelidade do qubit utilizado de 0 para 8: 0.9676509697368731
# 2024-12-13 12:27:34,523: Fidelidade do qubit utilizado de 0 para 8: 0.9617878910182779
# 2024-12-13 12:27:34,524: Fidelidade do qubit utilizado de 0 para 8: 0.9917396851769184
# 2024-12-13 12:27:34,525: Fidelidade do qubit utilizado de 0 para 8: 0.9786624059537014
# 2024-12-13 12:27:34,525: Fidelidade do qubit utilizado de 0 para 8: 0.9696520023485338
# 2024-12-13 12:27:34,526: Fidelidade do qubit utilizado de 0 para 8: 0.9791776232400563
# 2024-12-13 12:27:34,526: Fidelidade do qubit utilizado de 0 para 8: 0.9025891738930174
# 2024-12-13 12:27:34,527: Fidelidade do qubit utilizado de 0 para 8: 0.9016563096055864
# 2024-12-13 12:27:34,527: Fidelidade do qubit utilizado de 0 para 8: 0.9529766015417566
# 2024-12-13 12:27:34,528: A fidelidade média de todos os qubits utilizados na camada de transporte é 0.9585042216035665
# 0.9585042216035665

# %% [markdown]
# ##### A função get_timeslot apresenta quantos timeslot se passaram durante a execução da camada.

# %%
rede.get_timeslot()
# Out:
# 10

# %% [markdown]
# ##### Por meio do display_all_qubits_timeslot, pode-se verificar em qual timeslot cada qubit foi criado.

# %%
rede.display_all_qubit_timeslots()
# Out:
# Qubit 0 foi criado no timeslot 0
# Qubit 1 foi criado no timeslot 0
# Qubit 2 foi criado no timeslot 0
# Qubit 3 foi criado no timeslot 0
# Qubit 4 foi criado no timeslot 0
# Qubit 5 foi criado no timeslot 0
# Qubit 6 foi criado no timeslot 0
# Qubit 7 foi criado no timeslot 0
# Qubit 8 foi criado no timeslot 0
# Qubit 9 foi criado no timeslot 0
