# %%
from quantumnet.components import Network, Host
from quantumnet.components import ServerNode, ClientNode, RegularNode
from quantumnet.objects import Qubit, Logger
import random

# %%
# instanciando a rede
rede = Network()

# instanciando hosts (com tipos específicos, se necessário)
h1 = ServerNode(1)
h2 = ClientNode(2)
h3 = ClientNode(3)


# criando as conexões
h1.add_connection(2)
h1.add_connection(3)
h2.add_connection(3)

# adicionando hosts à rede
rede.add_host(h1)
rede.add_host(h2)
rede.add_host(h3)

# plotando a rede
rede.draw()

# %%
# o acesso dos nós e arestas do grafo da rede pode ser feito diretamente pela rede
print(rede.nodes)
print(rede.edges)
# ou pela propriedade graph da rede
print(rede.graph.nodes)
print(rede.graph.edges)
# Out:
# [1, 2, 3]
# [(1, 2), (1, 3), (2, 3)]
# [1, 2, 3]
# [(1, 2), (1, 3), (2, 3)]

# %%
rede = Network()
rede.set_ready_topology('grade',4,3,3)  # Exemplo de uma grade 3x3 com 2 clientes e 1 servidor
rede.draw()
Logger.activate(Logger)
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %%
rede.application_layer.run_app("AC_BQC",3,0,7)
# Out:
# 2024-10-10 00:47:15,724: Alice criou 7 qubits para a transmissão.
# 2024-10-10 00:47:15,726: Qubit 119 criado por Alice - Estado: 0, Fase: 1
# 2024-10-10 00:47:15,727: Qubit 177 criado por Alice - Estado: 0, Fase: 1
# 2024-10-10 00:47:15,728: Qubit 520 criado por Alice - Estado: 0, Fase: 1
# 2024-10-10 00:47:15,728: Qubit 169 criado por Alice - Estado: 0, Fase: 1
# 2024-10-10 00:47:15,729: Qubit 53 criado por Alice - Estado: 0, Fase: 1
# 2024-10-10 00:47:15,731: Qubit 903 criado por Alice - Estado: 0, Fase: 1
# 2024-10-10 00:47:15,731: Qubit 245 criado por Alice - Estado: 0, Fase: 1
# 2024-10-10 00:47:15,732: Instruções clássicas enviadas por Alice: ['Y', 'Z', 'Z', 'Z', 'Z', 'Z', 'Y']
# 2024-10-10 00:47:15,733: Erro: Alice tem 10 qubits, mas deveria ter 7 qubits. Abortando transmissão.
# 2024-10-10 00:47:15,733: Falha ao enviar os qubits para o servidor (Bob).
