# %%
from quantumnet.components import Network, Host
from quantumnet.components import ServerNode, ClientNode, RegularNode
from quantumnet.objects import Qubit, Logger
import random

# %%
# instanciando a rede
rede = Network()

# instanciando hosts (com tipos específicos, se necessário)
h1 = ServerNode(1)
h2 = ClientNode(2)
h3 = ClientNode(3)


# criando as conexões
h1.add_connection(2)
h1.add_connection(3)
h2.add_connection(3)

# adicionando hosts à rede
rede.add_host(h1)
rede.add_host(h2)
rede.add_host(h3)

# plotando a rede
rede.draw()

# %%
# o acesso dos nós e arestas do grafo da rede pode ser feito diretamente pela rede
print(rede.nodes)
print(rede.edges)
# ou pela propriedade graph da rede
print(rede.graph.nodes)
print(rede.graph.edges)
# Out:
# [1, 2, 3]
# [(1, 2), (1, 3), (2, 3)]
# [1, 2, 3]
# [(1, 2), (1, 3), (2, 3)]

# %%
rede = Network()
rede.set_ready_topology('grade',4,3,3)  # Exemplo de uma grade 3x3 com 2 clientes e 1 servidor
rede.draw()
Logger.activate(Logger)
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %%
rede.application_layer.run_app("AC_BQC",3,0,10)
# Out:
# 2024-10-08 17:03:32,987: Alice criou 10 qubits.
# 2024-10-08 17:03:32,988: Alice aplicou Y no qubit 749
# 2024-10-08 17:03:32,989: Alice aplicou Y no qubit 114
# 2024-10-08 17:03:32,990: Alice aplicou Y no qubit 621
# 2024-10-08 17:03:32,991: Alice aplicou X no qubit 755
# 2024-10-08 17:03:32,993: Alice aplicou X no qubit 883
# 2024-10-08 17:03:32,994: Alice aplicou I no qubit 909
# 2024-10-08 17:03:32,997: Alice aplicou I no qubit 708
# 2024-10-08 17:03:32,998: Alice aplicou X no qubit 570
# 2024-10-08 17:03:32,999: Alice aplicou Y no qubit 800
# 2024-10-08 17:03:33,000: Alice aplicou Z no qubit 845
# 2024-10-08 17:03:33,002: Verificação de contagem: Alice tem 10 qubits antes de enviar para Bob.
# 2024-10-08 17:03:33,003: Tentativa 1 de transmissão de qubits entre 3 e 0.
# 2024-10-08 17:03:33,004: Timeslot 1: Buscando rota válida entre 3 e 0.
# 2024-10-08 17:03:33,008: Rota válida encontrada: [3, 0]
# 2024-10-08 17:03:33,010: Teletransporte de qubit de 3 para 0 na rota [3, 0] foi bem-sucedido com fidelidade final de 0.2683680299308583.
# 2024-10-08 17:03:33,012: Timeslot 2: Buscando rota válida entre 3 e 0.
# 2024-10-08 17:03:33,013: Rota válida encontrada: [3, 0]
# 2024-10-08 17:03:33,015: Teletransporte de qubit de 3 para 0 na rota [3, 0] foi bem-sucedido com fidelidade final de 0.5151087129398744.
# 2024-10-08 17:03:33,017: Timeslot 3: Buscando rota válida entre 3 e 0.
# 2024-10-08 17:03:33,019: Rota válida encontrada: [3, 0]
# 2024-10-08 17:03:33,021: Teletransporte de qubit de 3 para 0 na rota [3, 0] foi bem-sucedido com fidelidade final de 0.40585209684918094.
# 2024-10-08 17:03:33,022: Timeslot 4: Buscando rota válida entre 3 e 0.
# 2024-10-08 17:03:33,024: Rota válida encontrada: [3, 0]
# 2024-10-08 17:03:33,026: Teletransporte de qubit de 3 para 0 na rota [3, 0] foi bem-sucedido com fidelidade final de 0.021719431406868602.
# 2024-10-08 17:03:33,027: Timeslot 5: Buscando rota válida entre 3 e 0.
# 2024-10-08 17:03:33,029: Rota válida encontrada: [3, 0]
# 2024-10-08 17:03:33,031: Teletransporte de qubit de 3 para 0 na rota [3, 0] foi bem-sucedido com fidelidade final de 0.07131033487781088.
# 2024-10-08 17:03:33,034: Timeslot 6: Buscando rota válida entre 3 e 0.
# 2024-10-08 17:03:33,034: Rota válida encontrada: [3, 0]
# 2024-10-08 17:03:33,035: Teletransporte de qubit de 3 para 0 na rota [3, 0] foi bem-sucedido com fidelidade final de 0.2500584291283578.
# 2024-10-08 17:03:33,035: Timeslot 7: Buscando rota válida entre 3 e 0.
# 2024-10-08 17:03:33,036: Rota válida encontrada: [3, 0]
# 2024-10-08 17:03:33,036: Teletransporte de qubit de 3 para 0 na rota [3, 0] foi bem-sucedido com fidelidade final de 0.13460855210945966.
# 2024-10-08 17:03:33,037: Timeslot 8: Buscando rota válida entre 3 e 0.
# 2024-10-08 17:03:33,037: Rota válida encontrada: [3, 0]
# 2024-10-08 17:03:33,038: Teletransporte de qubit de 3 para 0 na rota [3, 0] foi bem-sucedido com fidelidade final de 0.1288208116714926.
# 2024-10-08 17:03:33,039: Timeslot 9: Buscando rota válida entre 3 e 0.
# 2024-10-08 17:03:33,039: Rota válida encontrada: [3, 0]
# 2024-10-08 17:03:33,041: Teletransporte de qubit de 3 para 0 na rota [3, 0] foi bem-sucedido com fidelidade final de 0.05090291683851158.
# 2024-10-08 17:03:33,043: Timeslot 10: Buscando rota válida entre 3 e 0.
# 2024-10-08 17:03:33,044: Rota válida encontrada: [3, 0]
# 2024-10-08 17:03:33,046: Teletransporte de qubit de 3 para 0 na rota [3, 0] foi bem-sucedido com fidelidade final de 0.006096961316162883.
# 2024-10-08 17:03:33,048: Transmissão e teletransporte de 10 qubits entre 3 e 0 concluídos com sucesso. Timeslot: 10
# 2024-10-08 17:03:33,049: Alice enviou 10 qubits para Bob.
# 2024-10-08 17:03:33,051: Alice enviou as instruções clássicas: ['Y', 'Y', 'Y', 'X', 'X', 'I', 'I', 'X', 'Y', 'Z'].
# 2024-10-08 17:03:33,053: Bob aplicou as operações instruídas por Alice nos qubits.
# 2024-10-08 17:03:33,058: Verificação de contagem: Bob tem 10 qubits após aplicar as operações.
# 2024-10-08 17:03:33,060: Erro: Alice tem 20 qubits, mas deveria ter 10 qubits. Abortando transmissão.
# 2024-10-08 17:03:33,061: Falha ao devolver os qubits para Alice. Bob tinha 10 qubits.
